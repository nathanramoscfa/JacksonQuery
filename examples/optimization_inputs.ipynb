# %%
import os
import sys

# Add the root directory to the system path
sys.path.append(os.path.abspath(".."))

# %%
from portfolio_optimization import optimization_inputs as oi
from portfolio_optimization import optimization_data as od

# %%
oi.get_views().sort_values(ascending=False, by='VIEWS')
# Out:
#                                           TICKER  \
# SUBACCOUNT
# JNL_Mellon_Small_Cap_Index                  VIOO
# JNL_Mellon_Nasdaq_100_Index                  QQQ
# JNL_Mellon_S&P_400_MidCap_Index              IJH
# JNL_Mellon_Healthcare_Sector                 IYH
# JNL_Mellon_Information_Technology_Sector     IYW
# JNL_JPMorgan_MidCap_Growth                   IWP
# JNL_T_Rowe_Price_Mid_Cap_Growth              IWP
# JNL_PPM_America_Total_Return                SPBO
# JNL_WMC_Government_Money_Market              BIL
# JNL_T_Rowe_Price_Short_Term_Bond            ISTB
# JNL_Mellon_Bond_Index                        AGG
# JNL_JPMorgan_US_Government_&_Quality_Bond    BIV
# JNL_Mellon_Energy_Sector                     VDE
# JNL_Mellon_DowSM_Index                       DIA
# JNL_Mellon_Financial_Sector                  VFH
# JNL_American_Funds_Growth_Income             VOO
# JNL_Mellon_S&P_500_Index                     SPY
# JNL_DFA_US_Core_Equity                      SPLG
# ...

# %%
oi.get_views_dict()
# Out:
# {'JNL_Mellon_Nasdaq_100_Index': 0.1323,
#  'JNL_American_Funds_Growth_Income': 0.0205,
#  'JNL_T_Rowe_Price_Established_Growth': 0.0098,
#  'JNL_DFA_US_Core_Equity': 0.0205,
#  'JNL_JPMorgan_MidCap_Growth': 0.0667,
#  'JNL_T_Rowe_Price_Mid_Cap_Growth': 0.0667,
#  'JNL_JPMorgan_US_Government_&_Quality_Bond': 0.0409,
#  'JNL_Mellon_Bond_Index': 0.0445,
#  'JNL_Mellon_DowSM_Index': 0.0397,
#  'JNL_Mellon_Energy_Sector': 0.0403,
#  'JNL_Mellon_Financial_Sector': 0.0386,
#  'JNL_Mellon_Healthcare_Sector': 0.0788,
#  'JNL_Mellon_Information_Technology_Sector': 0.0739,
#  'JNL_Mellon_S&P_400_MidCap_Index': 0.1323,
#  'JNL_Mellon_S&P_500_Index': 0.0205,
#  'JNL_Mellon_Small_Cap_Index': 0.2268,
#  'JNL_PPM_America_Total_Return': 0.0541,
#  'JNL_T_Rowe_Price_Short_Term_Bond': 0.0452,
#  'JNL_WMC_Government_Money_Market': 0.052}

# %%
oi.compute_risk_aversion()
# Out:
# JNL_JPMorgan_US_Government_&_Quality_Bond         -5.3097
# JNL_T_Rowe_Price_Mid_Cap_Growth                    3.5748
# JNL_WMC_Government_Money_Market                 -563.0383
# JNL_Mellon_Bond_Index                             -4.2079
# JNL_T_Rowe_Price_Established_Growth                2.0137
# JNL_Mellon_S&P_500_Index                           3.9998
# JNL_Invesco_Small_Cap_Growth                       1.5573
# JNL_T_Rowe_Price_Short_Term_Bond                 -25.6784
# JNL_Mellon_S&P_400_MidCap_Index                    3.5594
# JNL_Mellon_International_Index                     1.3760
# JNL_Newton_Equity_Income                           4.8195
# JNL_Mellon_Healthcare_Sector                       6.1220
# JNL_Mellon_World_Index                             2.5815
# JNL_Mellon_Small_Cap_Index                         2.8581
# JNL_American_Funds_Growth_Income                   4.3691
# JNL_Mellon_Information_Technology_Sector           2.9085
# ...

# %%
oi.compute_prior_returns().sort_values(ascending=False)
# Out:
# JNL_Mellon_Healthcare_Sector                     0.0963
# JNL_Mellon_DowSM_Index                           0.0925
# JNL_Mellon_S&P_500_Index                         0.0910
# JNL_Mellon_Information_Technology_Sector         0.0896
# JNL_American_Funds_Growth_Income                 0.0895
# JNL_Mellon_Nasdaq_100_Index                      0.0856
# JNL_T_Rowe_Price_Mid_Cap_Growth                  0.0841
# JNL_DFA_US_Core_Equity                           0.0828
# JNL_Newton_Equity_Income                         0.0771
# JNL_Mellon_S&P_400_MidCap_Index                  0.0755
# JNL_JPMorgan_MidCap_Growth                       0.0731
# JNL_Mellon_Consumer_Discretionary_Sector         0.0712
# JNL_T_Rowe_Price_Established_Growth              0.0685
# JNL_American_Funds_Growth_Allocation             0.0682
# JNL_Mellon_Small_Cap_Index                       0.0665
# JNL_Mellon_Financial_Sector                      0.0655
# JNL_American_Funds_Moderate_Growth_Allocation    0.0606
# ...

# %%
oi.compute_posterior_returns().sort_values(ascending=False)
# Out:
# JNL_Mellon_Small_Cap_Index                       0.1063
# JNL_Mellon_Nasdaq_100_Index                      0.0934
# JNL_Invesco_Small_Cap_Growth                     0.0881
# JNL_Mellon_S&P_400_MidCap_Index                  0.0826
# JNL_Mellon_Information_Technology_Sector         0.0819
# JNL_Mellon_Consumer_Discretionary_Sector         0.0815
# JNL_JPMorgan_MidCap_Growth                       0.0754
# JNL_Invesco_Global_Growth                        0.0666
# JNL_T_Rowe_Price_Established_Growth              0.0646
# JNL_Mellon_Financial_Sector                      0.0631
# JNL_T_Rowe_Price_Mid_Cap_Growth                  0.0622
# JNL_DFA_US_Core_Equity                           0.0572
# JNL_Mellon_S&P_500_Index                         0.0556
# JNL_Mellon_World_Index                           0.0543
# JNL_Newton_Equity_Income                         0.0538
# JNL_American_Funds_Growth_Allocation             0.0509
# JNL_American_Funds_Growth_Income                 0.0491
# ...

# %%
oi.get_fees().sort_values(ascending=False)
# Out:
# Subaccount Name
# JNL_Multi_Manager_Alternative                     0.0449
# JNL_Westchester_Capital_Event_Driven              0.0389
# JNL_GQG_Emerging_Markets_Equity                   0.0367
# JNL_American_Funds_New_World                      0.0356
# JNL_American_Funds_Global_Small_Capitalization    0.0355
#                                                    ...
# JNL_Mellon_S&P_400_MidCap_Index                   0.0286
# JNL_Mellon_Bond_Index                             0.0286
# JNL_Mellon_Small_Cap_Index                        0.0286
# JNL_WMC_Government_Money_Market                   0.0286
# JNL_Mellon_S&P_500_Index                          0.0282
# Name: Fund Expense Fee%, Length: 115, dtype: float64

# %%
oi.compute_expected_returns().sort_values(ascending=False)
# Out:
# JNL_Mellon_Small_Cap_Index                       0.0777
# JNL_Mellon_Nasdaq_100_Index                      0.0639
# JNL_Invesco_Small_Cap_Growth                     0.0545
# JNL_Mellon_S&P_400_MidCap_Index                  0.0540
# JNL_Mellon_Information_Technology_Sector         0.0527
# JNL_Mellon_Consumer_Discretionary_Sector         0.0521
# JNL_JPMorgan_MidCap_Growth                       0.0435
# JNL_Invesco_Global_Growth                        0.0341
# JNL_Mellon_Financial_Sector                      0.0337
# JNL_T_Rowe_Price_Established_Growth              0.0333
# JNL_T_Rowe_Price_Mid_Cap_Growth                  0.0293
# JNL_Mellon_S&P_500_Index                         0.0274
# JNL_DFA_US_Core_Equity                           0.0262
# JNL_Mellon_World_Index                           0.0248
# JNL_Newton_Equity_Income                         0.0217
# JNL_Mellon_Healthcare_Sector                     0.0193
# JNL_American_Funds_Growth_Allocation             0.0179
# ...

# %%
oi.category_constraints()
# Out:
# {'mapper': {'JNL_American_Funds_Growth_Allocation': 'Moderately Aggressive Allocation',
#   'JNL_American_Funds_Growth_Income': 'Large Blend',
#   'JNL_American_Funds_Moderate_Growth_Allocation': 'Moderate Allocation',
#   'JNL_DFA_US_Core_Equity': 'Large Blend',
#   'JNL_Franklin_Templeton_Income': 'Moderate Allocation',
#   'JNL_Invesco_Global_Growth': 'Global Large-Stock Growth',
#   'JNL_Invesco_Small_Cap_Growth': 'Small Growth',
#   'JNL_JPMorgan_MidCap_Growth': 'Mid-Cap Growth',
#   'JNL_JPMorgan_US_Government_&_Quality_Bond': 'Intermediate Government',
#   'JNL_Mellon_Bond_Index': 'Intermediate Core Bond',
#   'JNL_Mellon_Consumer_Discretionary_Sector': 'Consumer Cyclical',
#   'JNL_Mellon_DowSM_Index': 'Large Value',
#   'JNL_Mellon_Energy_Sector': 'Equity Energy',
#   'JNL_Mellon_Financial_Sector': 'Financial',
#   'JNL_Mellon_Healthcare_Sector': 'Health',
#   'JNL_Mellon_Information_Technology_Sector': 'Technology',
# ...
