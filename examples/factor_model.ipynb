# %%
import os
import sys

# Add the root directory to the system path
sys.path.append(os.path.abspath(".."))

# %%
from portfolio_optimization import factor_data 
from portfolio_optimization import factor_model

# %%
data = factor_data.process_data()

# %%
# assuming you have `factor_data` and `classification_schema`
top_ranked = factor_model.analyze_factor_model(data, min_rank=0.7, display_heatmap=True)
# Out:
# Number of Top Ranked Sub-Accounts: 35

# %%
top_ranked
# Out:
#                                                              Morningstar Category  \
# Subaccount Name
# JNL_JPMorgan_US_Government_&_Quality_Bond                 Intermediate Government
# JNL_T_Rowe_Price_Mid_Cap_Growth                                    Mid-Cap Growth
# JNL_WMC_Government_Money_Market                              Money Market-Taxable
# JNL_Mellon_Bond_Index                                      Intermediate Core Bond
# JNL_T_Rowe_Price_Established_Growth                                  Large Growth
# JNL_Mellon_S&P_500_Index                                              Large Blend
# JNL_Invesco_Small_Cap_Growth                                         Small Growth
# JNL_T_Rowe_Price_Short_Term_Bond                                  Short-Term Bond
# JNL_Mellon_S&P_400_MidCap_Index                                     Mid-Cap Blend
# JNL_Mellon_International_Index                                Foreign Large Blend
# ...

# %%
data.loc['JNL_JPMorgan_US_Government_&_Quality_Bond']
# Out:
# Morningstar Category      Intermediate Government
# Management Fee%                               0.7
# Manager Tenure (Years)                      12.88
# Portfolio Turnover%                          18.8
# Name: JNL_JPMorgan_US_Government_&_Quality_Bond, dtype: object
