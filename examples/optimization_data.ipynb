# %%
import os
import sys

# Add the root directory to the system path
sys.path.append(os.path.abspath(".."))

# %%
from portfolio_optimization import optimization_data as od

# %%
od.load_classification_schema()
# Out:
#                                              Morningstar Category  \
# Subaccount Name
# JNL_Aggressive_Growth_Allocation            Aggressive Allocation
# JNL_American_Funds_Balanced                   Moderate Allocation
# JNL_American_Funds_Bond_Fund_of_America    Intermediate Core Bond
# JNL_American_Funds_Capital_Income_Builder       Global Allocation
# JNL_American_Funds_Capital_World_Bond                 Global Bond
# ...                                                           ...
# JNL_WMC_Balanced                              Moderate Allocation
# JNL_WMC_Equity_Income                                 Large Value
# JNL_WMC_Global_Real_Estate                     Global Real Estate
# JNL_WMC_Government_Money_Market              Money Market-Taxable
# JNL_WMC_Value                                         Large Value
#
#                                            Total Net Assets ($mil)  \
# Subaccount Name
# JNL_Aggressive_Growth_Allocation                           1378.83
# ...

# %%
od.load_views()
# Out:
#     TICKER                                               NAME   VIEWS
# 0     KBWB                               Invesco KBW Bank ETF  0.0701
# 1     ONEQ                Fidelity Nasdaq Composite Index ETF  0.0804
# 2      DVY                        iShares Select Dividend ETF  0.0664
# 3     BBRE             JPMorgan BetaBuilders MSCI US REIT ETF  0.0199
# 4      FRI                    First Trust S&P REIT Index Fund  0.0199
# ..     ...                                                ...     ...
# 337    VTC                 Vanguard Total Corporate Bond Fund  0.0533
# 338   VTIP  Vanguard Short-Term Inflation-Protected Securi...  0.0187
# 339   VWOB      Vanguard Emerging Markets Government Bond ETF  0.0758
# 340   WFHY       WisdomTree US High Yield Corporate Bond Fund  0.0849
# 341   ZROZ  PIMCO 25+ Year Zero Coupon U.S. Treasury Index...  0.0387
#
# [342 rows x 3 columns]

# %%
od.load_proxies()
# Out:
#                                                                        CATEGORY  \
# SUBACCOUNT
# JNL_American_Funds_Growth                                          Large Growth
# JNL_American_Funds_Growth_Income                                    Large Blend
# JNL_American_Funds_Washington_Mutual_Investors                      Large Value
# JNL_BlackRock_Large_Cap_Select_Growth                              Large Growth
# JNL_DFA_US_Core_Equity                                              Large Blend
# JNL_DFA_US_Small_Cap                                                Small Blend
# JNL_DoubleLine_Core_Fixed_Income                    Intermediate Core-Plus Bond
# JNL_Fidelity_Institutional_Asset_Management_Tot...  Intermediate Core-Plus Bond
# JNL_Goldman_Sachs_4                                                 Large Value
# JNL_JPMorgan_MidCap_Growth                                       Mid-Cap Growth
# JNL_JPMorgan_US_Government_&_Quality_Bond               Intermediate Government
# ...

# %%
od.load_total_net_assets()
# Out:
# Subaccount Name
# JNL_T_Rowe_Price_Capital_Appreciation    11661.20
# JNL_Mellon_S&P_500_Index                 11247.66
# JNL_American_Funds_Growth_Income          8895.36
# JNL_WMC_Balanced                          8689.07
# JNL_T_Rowe_Price_Established_Growth       8256.03
#                                            ...
# JNL_Heitman_US_Focused_Real_Estate         199.93
# JNL_iShares_Tactical_Moderate              199.27
# JNL_Mellon_Industrials_Sector              188.92
# JNL_Mellon_Real_Estate_Sector              176.92
# JNL_Westchester_Capital_Event_Driven       122.58
# Name: Total Net Assets ($mil), Length: 115, dtype: float64

# %%
od.load_factor_data()
# Out:
#                                                 Morningstar Category  \
# Subaccount Name
# JNL_American_Funds_Balanced                      Moderate Allocation
# JNL_American_Funds_Bond_Fund_of_America       Intermediate Core Bond
# JNL_American_Funds_Capital_Income_Builder          Global Allocation
# JNL_American_Funds_Capital_World_Bond                    Global Bond
# JNL_American_Funds_Global_Growth           Global Large-Stock Growth
# ...                                                              ...
# JNL_WMC_Balanced                                 Moderate Allocation
# JNL_WMC_Equity_Income                                    Large Value
# JNL_WMC_Global_Real_Estate                        Global Real Estate
# JNL_WMC_Government_Money_Market                 Money Market-Taxable
# JNL_WMC_Value                                            Large Value
#
#                                            Fund Expense Fee%  \
# Subaccount Name
# ...

# %%
od.load_risk_free_rate()
# Out:
# 0.0227

# %%
od.compute_top_ranked_subaccounts()
# Out:
#                                                            Morningstar Category  \
# Subaccount Name
# JNL_JPMorgan_US_Government_&_Quality_Bond               Intermediate Government
# JNL_T_Rowe_Price_Mid_Cap_Growth                                  Mid-Cap Growth
# JNL_WMC_Government_Money_Market                            Money Market-Taxable
# JNL_Mellon_Bond_Index                                    Intermediate Core Bond
# JNL_T_Rowe_Price_Established_Growth                                Large Growth
# JNL_Mellon_S&P_500_Index                                            Large Blend
# JNL_Invesco_Small_Cap_Growth                                       Small Growth
# JNL_T_Rowe_Price_Short_Term_Bond                                Short-Term Bond
# JNL_Mellon_S&P_400_MidCap_Index                                   Mid-Cap Blend
# JNL_Mellon_International_Index                              Foreign Large Blend
# ...

# %%
od.get_subaccount_prices()
# Out:
#             JNL_JPMorgan_US_Government_&_Quality_Bond  \
# 2012-12-31                                     1.0000
# 2013-12-31                                     0.9649
# 2014-12-31                                     1.0170
# 2015-12-31                                     1.0217
# 2016-12-31                                     1.0365
# 2017-12-31                                     1.0625
# 2018-12-31                                     1.0673
# 2019-12-31                                     1.1362
# 2020-12-31                                     1.2152
# 2021-12-31                                     1.1892
# 2022-12-31                                     1.0505
#
#             JNL_T_Rowe_Price_Mid_Cap_Growth  JNL_WMC_Government_Money_Market  \
# 2012-12-31                           1.0000                           1.0000
# 2013-12-31                           1.3650                           1.0000
# 2014-12-31                           1.5401                           1.0000
# ...

# %%
od.compute_covariance_matrix()
# Out:
#                                                JNL_JPMorgan_US_Government_&_Quality_Bond  \
# JNL_JPMorgan_US_Government_&_Quality_Bond                                       0.009295
# JNL_T_Rowe_Price_Mid_Cap_Growth                                                 0.003902
# JNL_WMC_Government_Money_Market                                                -0.000006
# JNL_Mellon_Bond_Index                                                           0.002284
# JNL_T_Rowe_Price_Established_Growth                                             0.005893
# JNL_Mellon_S&P_500_Index                                                        0.003124
# JNL_Invesco_Small_Cap_Growth                                                    0.006248
# JNL_T_Rowe_Price_Short_Term_Bond                                                0.000826
# JNL_Mellon_S&P_400_MidCap_Index                                                 0.002116
# ...
